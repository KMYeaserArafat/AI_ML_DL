# %%
import pandas as pd

# %%
data = pd.read_csv('HR_comma_sep.csv')
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)

# %%
left = data[data['left']==1]
left.shape
print(f"Leave the company : {left.shape[0]}")

retained = data[data['left']==0]
retained.shape
print(f"Continue the company to work : {retained.shape[0]}")
# Out:
# Leave the company : 3571
# Continue the company to work : 11428

# %% [markdown]
# 2. Plot bar charts showing impact of employee salaries on retention

# %%
# Impact  of salary on employee retention
import plotly.express as px

fig1 = px.bar(data, x="salary", y="left",color='salary', title="Impact  of salary on employee retention")
fig1.show()

# %%
# Department wise employee retention rate, 
fig2 = px.bar(data, x='Department', y='left',color='salary', title="Department wise employee retention rate")
fig2.show()

# %% [markdown]
# Now build logistic regression model using variables that were narrowed down in step 1

# %%
data1 = data[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years','salary']]
data1
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummiesData = pd.get_dummies(data1['salary']).astype(int)

data2 = pd.concat([data1,dummiesData], axis='columns')
data2 = data2.drop(data['salary'], axis='columns')
data2
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
from sklearn.model_selection import train_test_split

x = data[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years']]
y = data['salary']

x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.80)

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train,y_train)

model.predict([0.37,166,1])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# 0.49579131594299525

# %%
model.score(x_train,y_train)
# Out:
# 0.49579131594299525
